# %% [markdown]
# # Lecture 3: Errors and Exceptions
#
# Read the error messages for the code snippets below and use them to debug the code.

# %%
def print_message(day):
    messages = {
        'monday': 'Hello, world!',
        'tuesday': 'Today is Tuesday!',
        'wednesday': 'It is the middle of the week.',
        'thursday': 'Today is Donnerstag in German!',
        'friday': 'Last day of the week!',
        'saturday': 'Hooray for the weekend!',
        'sunday': 'Aw, the weekend is almost over.'
    }
    print(messages[day])

def print_friday_message():
    print_message('Friday')

print_friday_message()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [1], line 16
#      13 def print_friday_message():
#      14     print_message('Friday')
# ---> 16 print_friday_message()
#
# Cell In [1], line 14, in print_friday_message()
#      13 def print_friday_message():
# ---> 14     print_message('Friday')
#
# Cell In [1], line 11, in print_message(day)
#       1 def print_message(day):
#       2     messages = {
#       3         'monday': 'Hello, world!',
#       4         'tuesday': 'Today is Tuesday!',
#    (...)
#       9         'sunday': 'Aw, the weekend is almost over.'
#      10     }
# ---> 11     print(messages[day])
#
# KeyError: 'Friday'

# %%
def greet(name):
    greeting = 'hello " + name
    return greeting

greeting = greet('alice')
print(greeting)
# Out:
#   Cell In [12], line 2
#     greeting = 'hello " + name
#                ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
authrs = {
    "Charles Dickens": "1870",
    "William Thackeray": "1863",
    "Anthony Trollope": "1882",
    "Gerard Manley Hopkins": "1889"

for author date in authors.items{}:
    print "%s" % authors + " died in " + "%d." % Date
# Out:
#   Cell In [11], line 1
#     authrs = {
#              ^
# SyntaxError: '{' was never closed

# %%
def favorite_ice_cream():
    ice_creams = [
        'chocolate',
        'vanilla'
        'strawberry'
    )
    print(ice_creams[3])

favorite_ice_cream()
# Out:
#   Cell In [10], line 6
#     )
#     ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '[' on line 2

# %%
def sort_list(l):
    new_list = []
    while len(l) > 0:
        max_val = l.max()
        max_idx = l.index(max_val)
        num = l.pop(max_idx)
        new_list.append(num)
    return new_list

sort_list([4, 55, 3, 83, 9, 1, 20])
sort_list(['cat', 'dog', 'fish', 'horse'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [19], line 10
#       7         new_list.append(num)
#       8     return new_list
# ---> 10 sort_list([4, 55, 3, 83, 9, 1, 20])
#      11 sort_list(['cat', 'dog', 'fish', 'horse'])
#
# Cell In [19], line 4, in sort_list(l)
#       2 new_list = []
#       3 while len(l) > 0:
# ----> 4     max_val = l.max()
#       5     max_idx = l.index(max_val)
#       6     num = l.pop(max_idx)
#
# AttributeError: 'list' object has no attribute 'max'

# %%
def max(*a):
    res = a[0]
    for i in range(len(a)+1):
        if a[i] > res:
            res = a[i]
    return res

max(1, 6, 4, 8)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [22], line 8
#       5             res = a[i]
#       6     return res
# ----> 8 max(1, 6, 4, 8)
#
# Cell In [22], line 4, in max(*a)
#       2 res = a[0]
#       3 for i in range(len(a)+1):
# ----> 4     if a[i] > res:
#       5         res = a[i]
#       6 return res
#
# IndexError: tuple index out of range
